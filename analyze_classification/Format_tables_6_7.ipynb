# %%
import pandas as pd

# %%
# %run analysis_utils

# %%
# model_name_map={
# 'hvg': 'HVG',
# 'pca': 'PCA',
# 'scgpt': 'scGPT', 
# 'scgpt_cancer': 'scGPT [cancer]',
# 'scvi':'scVI',
# 'gf-6L-30M-i2048': 'GF-V1',
# 'gf-6L-30M-i2048_continue': 'GF-V1 [continue]',
# 'Geneformer-V2-104M_CLcancer': 'GF-V2 [cancer]',
# 'Geneformer-V2-104M': 'GF-V2',
# 'Geneformer-V2-104M_continue': 'GF-V2 [continue]',
# 'Geneformer-V2-316M': 'GF-V2-Deep',
# 'gf-6L-30M-i2048_finetune': 'GF-V1 [finetune]',
# 'Geneformer-V2-104M_finetune': 'GF-V2 [finetune]',

# }

# %%
# experiment_name_map=dict(pre_post ='Treatment Naive vs Anti PD1',
#                          chemo= 'Treatment Naive vs Neoadjuvant Chemo',
#                         luad2 = 'Treatment Naive vs TKI treated',
#                         luad1 = 'Early stage vs Late stage',
#                         outcome ='T-cell exhaustion',
#                         subtype= 'ER+ vs TNBC')

# %%
# def map_groups(exp):
#     exp = exp.lower()
#     if 'gf' in exp:
#         return 'geneformer'
#     elif 'geneformer' in exp:
#         return 'Geneformer'
#     elif 'scgpt' in exp:
#         return 'scGPT'
#     elif any(x in exp for x in ['hvg', 'pca', 'scvi']):
#         return 'Baseline'
#     else:
#         return 'other'  # optional fallback.

# %%
df = pd.read_csv('./metrics/auprc_avg.csv')

# df['model'] = df.experiment
df['exeriment'] = df.experiment_name.map(experiment_name_map)
df = df[df.experiment_name!='luad1']
df=df.round(3)
print(df)
# df['group'] = df.model.map(map_groups)
df.to_csv('./tables/Table5_AUPRC_avg.csv', index=False)
# Out:
#        experiment_name      experiment       group   mean  \
# 0   brca_full_pre_post           GF-V2  Geneformer  0.962
# 1   brca_full_pre_post  GF-V2 [cancer]  Geneformer  0.983
# 2   brca_full_pre_post      GF-V2-Deep  Geneformer  0.992
# 3   brca_full_pre_post         CellPLM       Other  0.894
# 4   brca_full_pre_post           GF-V1  Geneformer  0.941
# 5   brca_full_pre_post             HVG       Other  1.000
# 6   brca_full_pre_post             PCA       Other  0.978
# 7   brca_full_pre_post    scFoundation       Other  0.995
# 8   brca_full_pre_post           scGPT       scGPT  0.876
# 9   brca_full_pre_post  scGPT [cancer]       scGPT  0.945
# 10  brca_full_pre_post     SCimilarity       Other  0.952
# 11  brca_full_pre_post            scVI       Other  0.974
# 12     brca_full_chemo           GF-V2  Geneformer  0.567
# 13     brca_full_chemo  GF-V2 [cancer]  Geneformer  0.590
# 14     brca_full_chemo      GF-V2-Deep  Geneformer  0.617
# ...

# %%
df = pd.read_csv('./metrics/auprc_vote.csv')
# df.model = df.model.map(model_name_map)
df['exeriment'] = df.experiment_name.map(experiment_name_map)
df = df[df.experiment_name!='luad1']
df=df.round(3)
# df['group'] = df.exeriment.map(map_groups)
df.to_csv('./tables/Table6_AUPRC_vote.csv', index=False)

# %%
df = pd.read_csv('./metrics/auprc_mil.csv')
# df.model = df.model.map(model_name_map)
df['exeriment'] = df.experiment_name.map(experiment_name_map)
df = df[df.experiment_name!='luad1']
df=df.round(3)
# df['group'] = df.model.map(map_groups)
df.to_csv('./tables/Table7_AUPRC_mil.csv', index=False)

# %%
df
# Out:
#              model   mean experiment_name  \
# 0              HVG  0.983         subtype
# 1              PCA  1.000         subtype
# 2             scVI  1.000         subtype
# 3            scGPT  0.789         subtype
# 4   scGPT [cancer]  0.844         subtype
# 5            GF-V1  0.940         subtype
# 6            GF-V2  0.983         subtype
# 7   GF-V2 [cancer]  1.000         subtype
# 8       GF-V2-Deep  1.000         subtype
# 9              HVG  0.570           chemo
# 10             PCA  0.545           chemo
# 11            scVI  0.693           chemo
# 12           scGPT  0.448           chemo
# 13  scGPT [cancer]  0.623           chemo
# 14           GF-V1  0.569           chemo
# 15           GF-V2  0.579           chemo
# 16  GF-V2 [cancer]  0.607           chemo
# 17      GF-V2-Deep  0.633           chemo
# 18             HVG  0.850         outcome
# 19             PCA  0.823         outcome
# 20            scVI  0.833         outcome
# ...
