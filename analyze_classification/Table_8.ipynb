# %%
import os
from os import listdir
from os.path import isfile, join, dirname, basename
import pandas as pd

# %%
# %run analysis_utils.py

# %%
def collect_auprc_scores( clf='avg', base_dir='./outcomes'):
    all_results = []

    for subdir in os.listdir(base_dir):
        exp_path = os.path.join(base_dir, subdir)
        file_path = os.path.join(exp_path, f'{clf}.csv')
        if os.path.isfile(file_path):
                df = pd.read_csv(file_path, index_col=0)
                cross_table = df.pivot_table(
                    index="experiment",
                    columns="Metrics",
                    values="model",
                    aggfunc="mean"
                )
                cross_table['strategy'] = clf
                cross_table['exp'] = subdir
                # print(clf)
                all_results.append(cross_table)
    all_results_df = pd.concat(all_results)
    all_results_df['strategy'] =clf
    return all_results_df

# %%
df = collect_auprc_scores( clf='avg', base_dir='./metrics')
df
# Out:
# Metrics                           AUC     AUPRC  Accuracy        F1  \
# experiment
# Geneformer-V2-104M           0.955556  0.962188  0.903846  0.901658
# Geneformer-V2-104M_CLcancer  0.978571  0.983333  0.903846  0.903313
# Geneformer-V2-316M           0.988889  0.991667  0.902564  0.901195
# cellplm                      0.857540  0.893817  0.805128  0.803104
# gf-6L-30M-i2048              0.934127  0.940952  0.835897  0.834246
# hvg                          1.000000  1.000000  0.983333  0.983217
# pca                          0.977381  0.978061  0.905128  0.904895
# scfoundation                 0.997222  0.995238  0.966667  0.966434
# scgpt                        0.844444  0.875589  0.723077  0.716778
# scgpt_cancer                 0.939683  0.944921  0.835897  0.831079
# scimilarity                  0.953175  0.951553  0.853846  0.852711
# scvi                         0.968651  0.973696  0.887179  0.886044
# Geneformer-V2-104M           0.776190  0.566667  0.846429  0.589304
# Geneformer-V2-104M_CLcancer  0.754762  0.590000  0.846429  0.589304
# Geneformer-V2-316M           0.846429  0.616667  0.821429  0.516044
# cellplm                      0.666667  0.590000  0.796429  0.588278
# gf-6L-30M-i2048              0.866667  0.750000  0.817857  0.580330
# hvg                          0.816667  0.640000  0.796429  0.442784
# pca                          0.669048  0.506667  0.796429  0.442784
# scfoundation                 0.763095  0.546667  0.821429  0.516044
# scgpt                        0.721429  0.618571  0.821429  0.516044
# scgpt_cancer                 0.821429  0.690000  0.821429  0.580513
# scimilarity                  0.800000  0.786667  0.821429  0.516044
# scvi                         0.827381  0.583333  0.796429  0.442784
# Geneformer-V2-104M           1.000000  1.000000  1.000000  1.000000
# Geneformer-V2-104M_CLcancer  1.000000  1.000000  1.000000  1.000000
# Geneformer-V2-316M           1.000000  1.000000  1.000000  1.000000
# cellplm                      1.000000  1.000000  1.000000  1.000000
# gf-6L-30M-i2048              1.000000  1.000000  1.000000  1.000000
# hvg                          1.000000  1.000000  1.000000  1.000000
# pca                          0.500000  0.750000  0.500000  0.416667
# scfoundation                 1.000000  1.000000  1.000000  1.000000
# scgpt                        1.000000  1.000000  1.000000  1.000000
# scgpt_cancer                 1.000000  1.000000  1.000000  1.000000
# scimilarity                  1.000000  1.000000  0.875000  0.833333
# scvi                         1.000000  1.000000  1.000000  1.000000
# Geneformer-V2-104M           0.866667  0.901111  0.726667  0.725714
# Geneformer-V2-104M_CLcancer  0.955556  0.973333  0.866667  0.864762
# Geneformer-V2-316M           0.933333  0.956667  0.860000  0.857143
# cellplm                      0.922222  0.934444  0.860000  0.857143
# gf-6L-30M-i2048              0.900000  0.912222  0.826667  0.822857
# hvg                          0.966667  0.973333  0.860000  0.859048
# pca                          0.922222  0.916667  0.860000  0.850714
# scfoundation                 0.766667  0.777778  0.740000  0.688810
# scgpt                        0.855556  0.862222  0.793333  0.780952
# scgpt_cancer                 0.933333  0.956667  0.900000  0.899048
# scimilarity                  0.916667  0.900000  0.773333  0.716667
# scvi                         0.977778  0.983333  0.933333  0.931429
# Geneformer-V2-104M           0.687500  0.630000  0.760000  0.605000
# Geneformer-V2-104M_CLcancer  0.750000  0.740000  0.826667  0.725000
# Geneformer-V2-316M           0.775000  0.783333  0.833333  0.777778
# cellplm                      0.625000  0.550000  0.626667  0.441111
# gf-6L-30M-i2048              0.587500  0.616667  0.653333  0.532698
# hvg                          0.850000  0.883333  0.826667  0.725000
# pca                          0.500000  0.580000  0.700000  0.506667
# scfoundation                 0.800000  0.816667  0.866667  0.836111
# scgpt                        0.687500  0.706667  0.726667  0.574444
# scgpt_cancer                 0.825000  0.873333  0.760000  0.652698
# scimilarity                  0.787500  0.746667  0.760000  0.730079
# scvi                         0.825000  0.833333  0.866667  0.836111
#
# Metrics                      Precision    Recall strategy                 exp
# experiment
# Geneformer-V2-104M            0.927381  0.907143      avg  brca_full_pre_post
# Geneformer-V2-104M_CLcancer   0.917857  0.907143      avg  brca_full_pre_post
# Geneformer-V2-316M            0.921429  0.904762      avg  brca_full_pre_post
# cellplm                       0.820119  0.804762      avg  brca_full_pre_post
# gf-6L-30M-i2048               0.849286  0.838095      avg  brca_full_pre_post
# hvg                           0.985714  0.983333      avg  brca_full_pre_post
# pca                           0.911905  0.907143      avg  brca_full_pre_post
# scfoundation                  0.971429  0.966667      avg  brca_full_pre_post
# scgpt                         0.751786  0.728571      avg  brca_full_pre_post
# scgpt_cancer                  0.868095  0.838095      avg  brca_full_pre_post
# scimilarity                   0.863095  0.854762      avg  brca_full_pre_post
# scvi                          0.902381  0.890476      avg  brca_full_pre_post
# Geneformer-V2-104M            0.619643  0.600000      avg     brca_full_chemo
# Geneformer-V2-104M_CLcancer   0.619643  0.600000      avg     brca_full_chemo
# Geneformer-V2-316M            0.508929  0.550000      avg     brca_full_chemo
# cellplm                       0.565476  0.616667      avg     brca_full_chemo
# gf-6L-30M-i2048               0.617262  0.583333      avg     brca_full_chemo
# hvg                           0.398214  0.500000      avg     brca_full_chemo
# pca                           0.398214  0.500000      avg     brca_full_chemo
# scfoundation                  0.508929  0.550000      avg     brca_full_chemo
# scgpt                         0.508929  0.550000      avg     brca_full_chemo
# scgpt_cancer                  0.616071  0.583333      avg     brca_full_chemo
# scimilarity                   0.508929  0.550000      avg     brca_full_chemo
# scvi                          0.398214  0.500000      avg     brca_full_chemo
# Geneformer-V2-104M            1.000000  1.000000      avg               luad2
# Geneformer-V2-104M_CLcancer   1.000000  1.000000      avg               luad2
# Geneformer-V2-316M            1.000000  1.000000      avg               luad2
# cellplm                       1.000000  1.000000      avg               luad2
# gf-6L-30M-i2048               1.000000  1.000000      avg               luad2
# hvg                           1.000000  1.000000      avg               luad2
# pca                           0.375000  0.500000      avg               luad2
# scfoundation                  1.000000  1.000000      avg               luad2
# scgpt                         1.000000  1.000000      avg               luad2
# scgpt_cancer                  1.000000  1.000000      avg               luad2
# scimilarity                   0.812500  0.875000      avg               luad2
# scvi                          1.000000  1.000000      avg               luad2
# Geneformer-V2-104M            0.741667  0.733333      avg   brca_full_subtype
# Geneformer-V2-104M_CLcancer   0.883333  0.866667      avg   brca_full_subtype
# Geneformer-V2-316M            0.891667  0.866667      avg   brca_full_subtype
# cellplm                       0.891667  0.866667      avg   brca_full_subtype
# gf-6L-30M-i2048               0.841667  0.833333      avg   brca_full_subtype
# hvg                           0.875000  0.866667      avg   brca_full_subtype
# pca                           0.901667  0.866667      avg   brca_full_subtype
# scfoundation                  0.735000  0.733333      avg   brca_full_subtype
# scgpt                         0.825000  0.783333      avg   brca_full_subtype
# scgpt_cancer                  0.908333  0.900000      avg   brca_full_subtype
# scimilarity                   0.770000  0.766667      avg   brca_full_subtype
# scvi                          0.950000  0.933333      avg   brca_full_subtype
# Geneformer-V2-104M            0.631667  0.625000      avg   brca_full_outcome
# Geneformer-V2-104M_CLcancer   0.765000  0.725000      avg   brca_full_outcome
# Geneformer-V2-316M            0.820000  0.775000      avg   brca_full_outcome
# cellplm                       0.436667  0.475000      avg   brca_full_outcome
# gf-6L-30M-i2048               0.546667  0.550000      avg   brca_full_outcome
# hvg                           0.765000  0.725000      avg   brca_full_outcome
# pca                           0.460000  0.575000      avg   brca_full_outcome
# scfoundation                  0.885000  0.825000      avg   brca_full_outcome
# scgpt                         0.576667  0.600000      avg   brca_full_outcome
# scgpt_cancer                  0.720000  0.650000      avg   brca_full_outcome
# scimilarity                   0.755000  0.750000      avg   brca_full_outcome
# scvi                          0.885000  0.825000      avg   brca_full_outcome

# %%
strategy = ['avg', 'vote', 'mil']
all_results= []
for s in strategy:
    df = collect_auprc_scores( clf=s, base_dir='./metrics')
    all_results.append(df)

all_df =pd.concat(all_results)

# %%
all_df = all_df[all_df.exp !='luad1']

# %%
all_df = all_df.reset_index(names= 'model')

# %%
all_df.model = all_df.model.map(model_name_map)

# %%
all_df
# Out:
# Metrics           model       AUC     AUPRC  Accuracy        F1  Precision  \
# 0                 GF-V2  0.955556  0.962188  0.903846  0.901658   0.927381
# 1        GF-V2 [cancer]  0.978571  0.983333  0.903846  0.903313   0.917857
# 2            GF-V2-Deep  0.988889  0.991667  0.902564  0.901195   0.921429
# 3               CellPLM  0.857540  0.893817  0.805128  0.803104   0.820119
# 4                 GF-V1  0.934127  0.940952  0.835897  0.834246   0.849286
# ..                  ...       ...       ...       ...       ...        ...
# 175        scFoundation  0.825000  0.833333  0.653333  0.644286   0.723333
# 176               scGPT  0.725000  0.723333  0.693333  0.408889   0.346667
# 177      scGPT [cancer]  0.700000  0.640000  0.693333  0.408889   0.346667
# 178         SCimilarity  0.775000  0.790000  0.686667  0.663810   0.683333
# 179                scVI  0.775000  0.780000  0.726667  0.699603   0.730000
#
# Metrics    Recall strategy                 exp
# 0        0.907143      avg  brca_full_pre_post
# 1        0.907143      avg  brca_full_pre_post
# 2        0.904762      avg  brca_full_pre_post
# 3        0.804762      avg  brca_full_pre_post
# 4        0.838095      avg  brca_full_pre_post
# ..            ...      ...                 ...
# 175      0.725000      mil   brca_full_outcome
# 176      0.500000      mil   brca_full_outcome
# 177      0.500000      mil   brca_full_outcome
# 178      0.700000      mil   brca_full_outcome
# 179      0.725000      mil   brca_full_outcome
#
# [180 rows x 9 columns]

# %%
all_df['exeriment'] = all_df.exp.map(experiment_name_map)

# %%
all_df= all_df.round(3)

# %%
all_df
# Out:
# Metrics           model    AUC  AUPRC  Accuracy     F1  Precision  Recall  \
# 0                 GF-V2  0.956  0.962     0.904  0.902      0.927   0.907
# 1        GF-V2 [cancer]  0.979  0.983     0.904  0.903      0.918   0.907
# 2            GF-V2-Deep  0.989  0.992     0.903  0.901      0.921   0.905
# 3               CellPLM  0.858  0.894     0.805  0.803      0.820   0.805
# 4                 GF-V1  0.934  0.941     0.836  0.834      0.849   0.838
# ..                  ...    ...    ...       ...    ...        ...     ...
# 175        scFoundation  0.825  0.833     0.653  0.644      0.723   0.725
# 176               scGPT  0.725  0.723     0.693  0.409      0.347   0.500
# 177      scGPT [cancer]  0.700  0.640     0.693  0.409      0.347   0.500
# 178         SCimilarity  0.775  0.790     0.687  0.664      0.683   0.700
# 179                scVI  0.775  0.780     0.727  0.700      0.730   0.725
#
# Metrics strategy                 exp                    exeriment
# 0            avg  brca_full_pre_post  Treatment Naive vs Anti PD1
# 1            avg  brca_full_pre_post  Treatment Naive vs Anti PD1
# 2            avg  brca_full_pre_post  Treatment Naive vs Anti PD1
# 3            avg  brca_full_pre_post  Treatment Naive vs Anti PD1
# 4            avg  brca_full_pre_post  Treatment Naive vs Anti PD1
# ..           ...                 ...                          ...
# 175          mil   brca_full_outcome            T-cell exhaustion
# 176          mil   brca_full_outcome            T-cell exhaustion
# 177          mil   brca_full_outcome            T-cell exhaustion
# 178          mil   brca_full_outcome            T-cell exhaustion
# 179          mil   brca_full_outcome            T-cell exhaustion
#
# [180 rows x 10 columns]

# %%
all_df.to_csv('./tables/Tabel8_classification_metrics.csv', index=False)

# %%
all_df.strategy.value_counts()
# Out:
# strategy
# avg     60
# vote    60
# mil     60
# Name: count, dtype: int64
