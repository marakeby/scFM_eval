# %%
import pandas as pd

# %%
# %run analysis_utils.py

# %%
df = pd.read_csv ('./fig2_metrics/metrics_10samples_mean.csv')
df = df[~df.model.str.startswith('__')]
df.model = df.model.map(model_name_map)
df = df[df['model'] != 'GF-V2 [continue]']
df['group'] = df.model.map(map_groups)
df= df.round(3)
df[['model', 'NMI_cluster/label','ARI_cluster/label', 'ASW_label', 'group']].to_csv('./tables/Table1_embedding_metrics_mean.csv', index=False)

# %%
df = pd.read_csv ('./fig2_metrics/metrics_10samples_std.csv')
df = df[~df.model.str.startswith('__')]
df.model = df.model.map(model_name_map)
df = df[df['model'] != 'GF-V2 [continue]']
df['group'] = df.model.map(map_groups)
df= df.round(3)
df[['model', 'NMI_cluster/label','ARI_cluster/label', 'ASW_label']].to_csv('./tables/Table2_embedding_metrics_std.csv', index=False)

# %%
df = pd.read_csv ('./fig2_metrics/metrics_10_runs.csv')
df = df[~df.method.str.startswith('__')]
# df
df['model'] = df.method.map(model_name_map)
df = df[df['model'] != 'GF-V2 [continue]']
df['group'] = df.model.map(map_groups)
df= df.round(3)
df[['model', 'NMI_cluster/label','ARI_cluster/label', 'ASW_label']].to_csv('./tables/Table3_embedding_metrics_10_runs.csv', index=False)

# %%
df
# Out:
#                           method  NMI_cluster/label  ARI_cluster/label  \
# 10   Geneformer-V2-104M_CLcancer              0.634              0.451
# 11   Geneformer-V2-104M_CLcancer              0.687              0.596
# 12   Geneformer-V2-104M_CLcancer              0.636              0.541
# 13   Geneformer-V2-104M_CLcancer              0.677              0.586
# 14   Geneformer-V2-104M_CLcancer              0.621              0.389
# ..                           ...                ...                ...
# 135     gf-6L-30M-i2048_continue              0.711              0.663
# 136     gf-6L-30M-i2048_continue              0.758              0.706
# 137     gf-6L-30M-i2048_continue              0.724              0.674
# 138     gf-6L-30M-i2048_continue              0.753              0.700
# 139     gf-6L-30M-i2048_continue              0.684              0.627
#
#      ASW_label  graph_conn  ASW_batch  ASW_label/batch  PCR_batch  avg_bio  \
# 10       0.509       0.951      0.437            0.827      0.171    0.531
# 11       0.509       0.961      0.441            0.833      0.177    0.598
# 12       0.509       0.956      0.437            0.842      0.180    0.562
# 13       0.509       0.959      0.439            0.852      0.169    0.591
# 14       0.511       0.985      0.436            0.836      0.169    0.507
# ..         ...         ...        ...              ...        ...      ...
# 135      0.500       0.973      0.472            0.870      0.148    0.625
# 136      0.504       0.968      0.471            0.884      0.151    0.656
# 137      0.516       0.964      0.471            0.877      0.156    0.638
# 138      0.502       0.978      0.472            0.873      0.145    0.652
# 139      0.511       0.987      0.473            0.869      0.151    0.608
#
#           group             model
# 10   Geneformer    GF-V2 [cancer]
# 11   Geneformer    GF-V2 [cancer]
# 12   Geneformer    GF-V2 [cancer]
# 13   Geneformer    GF-V2 [cancer]
# 14   Geneformer    GF-V2 [cancer]
# ..          ...               ...
# 135  Geneformer  GF-V1 [continue]
# 136  Geneformer  GF-V1 [continue]
# 137  Geneformer  GF-V1 [continue]
# 138  Geneformer  GF-V1 [continue]
# 139  Geneformer  GF-V1 [continue]
#
# [130 rows x 11 columns]
